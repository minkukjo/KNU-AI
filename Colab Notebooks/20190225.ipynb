# %%
# KNU AI Lecture
import numpy as np

# %%
a = np.array((0,10,20,30))

# %%
b = np.array((0,1,2))

# %%
y = a[:,None] + b

# %%
print(y)
# Out:
# [[ 0  1  2]
#  [10 11 12]
#  [20 21 22]
#  [30 31 32]]
